# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
import statistics

# %%
binom_data = np.random.binomial(n=1000, p=0.5, size=1000)

# %%
plt.hist(binom_data)
plt.show()

# %%
normal_data = np.random.normal(500, 50, 1000)

# %%
plt.hist(normal_data)
plt.show()

# %%
uniform_data = np.random.uniform(low=0, high=1, size=1000)

# %%
plt.hist(uniform_data)
plt.show()

# %%
binom_10_data = np.random.binomial(n=10, p=0.5, size=10)
binom_100_data = np.random.binomial(n=10, p=0.5, size=100)
binom_1000_data = np.random.binomial(n=10, p=0.5, size=1000)
binom_10000_data = np.random.binomial(n=10, p=0.5, size=10000)
binom_100000_data = np.random.binomial(n=10, p=0.5, size=100000)

# %%
plt.hist(binom_10_data)
plt.show()
plt.hist(binom_100_data)
plt.show()
plt.hist(binom_1000_data)
plt.show()
plt.hist(binom_10000_data)
plt.show()
plt.hist(binom_100000_data)
plt.show()
